# %% [markdown]
# <a href="https://colab.research.google.com/github/sadineniManushree/flyrank--internship__ml/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sadineniManushree/flyrank--internship__ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I selected the CTR / Engagement Opportunity Scoring lane because it focuses on predicting which content is most likely to receive higher click-through rates (CTR) and user engagement. This project helps identify high-potential content that can be optimized to improve visibility and user interaction. I chose this lane because it allows me to apply machine learning techniques to a practical business problem while learning about predictive modeling and data analysis.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Selected lane
lane = "CTR / Engagement Opportunity Scoring"
print("Selected Lane:", lane)
# Out:
# Selected Lane: CTR / Engagement Opportunity Scoring

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: Decide which content should be prioritized to improve click-through rate (CTR) and user engagement.
# action:Content managers, SEO teams, and marketing teams use the recommendation to optimize content.
# Cost of a wrong recommendation: If the model ranks content incorrectly, valuable content may be ignored while low-performing content is prioritized. This can reduce clicks, user engagement, and waste time and resources.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All. decision = "Rank content by CTR opportunit
print("be prioritized to improve click-through rate (CTR) ")
print("Content managers, SEO teams, and marketing teams use the recommendation to optimize content.")
print("If the model ranks content incorrectly, valuable content may be ignored while low-performing content is prioritized. ")
# Out:
# be prioritized to improve click-through rate (CTR)
# Content managers, SEO teams, and marketing teams use the recommendation to optimize content.
# If the model ranks content incorrectly, valuable content may be ignored while low-performing content is prioritized.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains 3000 rows and 44 columns. The sample records show information such as impressions, clicks, CTR, and other content features. These values indicate that the dataset is suitable for building a CTR prediction model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
rows=30000
columns=44
print("Number of rows:",rows)
print("Number of columns:",columns)
print("The dataset is suitable foe CTR and engagement analysis.")
# Out:
# Number of rows: 30000
# Number of columns: 44
# The dataset is suitable foe CTR and engagement analysis.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# I can claim that the model predicts the likelihood of higher CTR based on the available data. I cannot claim that the predictions are always correct or that improving CTR is guaranteed. The model provides recommendations that should be validated before making business decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Predictions are recommendations, not guarantees.")
# Out:
# Predictions are recommendations, not guarantees.

# %% [markdown]
# I can claim that the model predicts the likelihood of higher CTR based on the available data. I cannot claim that the predictions are always correct or that improving CTR is guaranteed. The model provides recommendations that should be validated before making business decisions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
