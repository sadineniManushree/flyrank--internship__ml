# %% [markdown]
# <a href="https://colab.research.google.com/github/sadineniManushree/flyrank--internship__ml/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sadineniManushree/flyrank--internship__ml/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# "My lane is a ranking/scoring task.Because the goal is to sort pages by how much their actual CTR underperforms their expected CTR (adjusted for position and volume), so editors can prioritize the biggest gaps first."

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
lane="CTR/Enagement Opportunity scoring"
task_type="scoring"
print("Lane : ",lane)
print("ML Task Type :",task_type)
# Out:
# Lane :  CTR/Enagement Opportunity scoring
# ML Task Type : scoring

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# "My target is a defined rule, built from real observed numbers (clicks, impressions, position), but the opportunity score itself is a formula  created — not something directly observed in the world."

# %%
clicks = 100
impressions = 1000
position = 5

opportunity_score = (clicks / impressions) * (1 / position)
target = opportunity_score

print(target)
# Out:
# 0.020000000000000004

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# My metric is precision out of the top 20 pages my score ranks as highest opportunity.'Good' means most of my top-flagged pages are real opportunities, not noise ,so editors trust the list and don't waste time on false alarms."

# %%
metric = "Precision@20"
good = "High precision means most of the top 20 ranked pages are true opportunities."

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# One row = one page, on one day

# %% [markdown]
# One row = one page.

# %%
import pandas as pd
df = pd.DataFrame({
    "page": ["/home", "/blog", "/contact"],
    "date": ["2026-08-01", "2026-08-01", "2026-08-01"],
    "clicks": [120, 80, 30],
    "impressions": [1000, 900, 400],
    "position": [3, 5, 8]
})
print(df)
# Out:
#        page        date  clicks  impressions  position
# 0     /home  2026-08-01     120         1000         3
# 1     /blog  2026-08-01      80          900         5
# 2  /contact  2026-08-01      30          400         8

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# if-statement that accounts for all .it explodes into hundreds of nested if-elif-else rules, and even then, it won't capture how these things interact with each other like position,volume and query.

# %%
rule = "if ctr < 0.05 and position <= 10: opportunity = True"
reason = "ML learns complex patterns from multiple features instead of relying on one fixed if-statement."

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
